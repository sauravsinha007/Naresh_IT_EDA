# %%
######## Exploratory Data Analysis #####
1. Pandass (Data frame analysis)
2. Numpy (Number Python math package)
3. Matplotlib (ploting/graph/visualization)
4. Seaborn (ploting/graph/visualization)
5. ploty (ploting/graph/visualization)
6. Bokhe (ploting/graph/visualization)

####### Machinne Learning ########
7. Scikit-learn (ML models will available)
8. Stats (Statistical models)

######## Deep Learning ############
9. Tensorflow (Developed by Google)
10. Keras 
11. Torch
12. OpenCV (Computer Vision) opencv by sentdex (youtuber)

################## NLP ###################
13. NLTK (Natural Language Tool Kit)
14. Scipy
################### GenAI (LLLM) ################
### Prompt Engineering ########
15. ChatGPT is developed by OpenAI + Azure
16. MakerSuite is developed by Google
17. Gemini is developed by Google

####### Company Based Packages ########
18. HuggingFace
    Transformers BERT models
    DL ML NLP all task it will do
    
19. AllenNLP

####### Special Packages ###########
20. Random
21. Time
22. Math
23. API     Flask
24. UI APPS Streamlit

# %%
Data Analysis
ML
DL
NLP
BERT : Transformers
LLM  : GenAI

# %%
CV computer Vision
Deep learning
Read any image video
OpenCV by Sentdex

# %% [markdown]
# ## Reading the data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# File floder
# file name
# file path

file_location = "C:\\Users\\HP\\OneDrive\\Saurav-Personal\\Documents\\NareshIT\\DataScience\\Datafiles\\Visadataset.csv"

# %%
dir(pd)
# Out:
# ['ArrowDtype',
#  'BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_config',
#  '_is_numpy_dev',
#  '_libs',
# ...

# %%
pd.read_csv(file_location)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
type(pd)
# Out:
# module

# %%
file_location1 = "C:\\Users\\HP\\OneDrive\\Saurav-Personal\\Documents\\NareshIT\\DataScience\\Datafiles\\bank.csv"

# %%
pd.read_csv(file_location1,sep=';')
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
file_location3 = "C:\\Users\\HP\\OneDrive\\Saurav-Personal\\Documents\\NareshIT\\DataScience\\Datafiles\\Visadataset.excel"
pd.read_excel(file_location3)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 2
#       1 file_location3 = "C:\\Users\\HP\\OneDrive\\Saurav-Personal\\Documents\\NareshIT\\DataScience\\Datafiles\\Visadataset.excel"
# ----> 2 pd.read_excel(file_location3)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:478, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     476 if not isinstance(io, ExcelFile):
#     477     should_close = True
# --> 478     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     479 elif engine and engine != io.engine:
#     480     raise ValueError(
# ...

# %% [markdown]
# $ Method$-$1$

# %% [markdown]
# ## Create dataframe using list

# %% [markdown]
# $Step-1:$
#
# **Create a new dataframe**

# %%
Names = ['Ramesh','Suresh','Sathish']
Age = [20,25,30]
pd.DataFrame(zip(Names,Age))
# Out:
#          0   1
# 0   Ramesh  20
# 1   Suresh  25
# 2  Sathish  30

# %% [markdown]
# $Step-2:$
#
# **Update the Column name**

# %%
Names = ['Ramesh','Suresh','Sathish']
Age = [20,25,30]
pd.DataFrame(zip(Names,Age), 
             columns = ['Name','Age'])
# Out:
#       Name  Age
# 0   Ramesh   20
# 1   Suresh   25
# 2  Sathish   30

# %%
Names = ['Ramesh','Suresh','Sathish']
Age = [20,25,30]
pd.DataFrame(zip(Names,Age),
             columns = ['Name','Age'],
             index = ['A','B','C']
            )
# Out:
#       Name  Age
# A   Ramesh   20
# B   Suresh   25
# C  Sathish   30

# %%
Names = ['Ramesh','Suresh','Sathish']
Age = [20,25,30]
pd.DataFrame(zip(Names,Age),
             columns = ['Name','Age'],
             index = ['A','B',100]
            )
# Out:
#         Name  Age
# A     Ramesh   20
# B     Suresh   25
# 100  Sathish   30

# %%
# create one more column

Names = ['Ramesh','Suresh','Sathish']
Age = [20,25,30]
df1 = pd.DataFrame(zip(Names,Age),
             columns = ['Name','Age'],
             index = ['A','B',100]
            )
df1
# Out:
#         Name  Age
# A     Ramesh   20
# B     Suresh   25
# 100  Sathish   30

# %%
df1['Name']
# Out:
# A       Ramesh
# B       Suresh
# 100    Sathish
# Name: Name, dtype: object

# %%
df1['Name'] = ['Satish','Suresh','Ramesh']
df1
# Out:
#        Name  Age
# A    Satish   20
# B    Suresh   25
# 100  Ramesh   30

# %%
df1['Name'] = ['Satish','Suresh']
df1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df1['Name'] = ['Satish','Suresh']
#       2 df1
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3950, in DataFrame.__setitem__(self, key, value)
#    3947     self._setitem_array([key], value)
#    3948 else:
#    3949     # set column
# -> 3950     self._set_item(key, value)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4143, in DataFrame._set_item(self, key, value)
#    4133 def _set_item(self, key, value) -> None:
#    4134     """
#    4135     Add series to DataFrame in specified column.
#    4136
#    (...)
#    4141     ensure homogeneity.
#    4142     """
# -> 4143     value = self._sanitize_column(value)
#    4145     if (
#    4146         key in self.columns
#    4147         and value.ndim == 1
#    4148         and not is_extension_array_dtype(value)
# ...

# %%
# Add a new column
df1['City'] = ['Hyd','Mumbai','Chennai']
df1
# Out:
#        Name  Age     City
# A    Satish   20      Hyd
# B    Suresh   25   Mumbai
# 100  Ramesh   30  Chennai

# %%
# Add a row
print(df1.index)
print(len(df1.index))
# Out:
# Index(['A', 'B', 100], dtype='object')
# 3

# %%
Names = ['Ramesh','Suresh','Sathish']
Age = [20,25,30]
df2 = pd.DataFrame(zip(Names,Age),
             columns = ['Name','Age'],
             index = [1,2,3]
            )
df2
# Out:
#       Name  Age
# 1   Ramesh   20
# 2   Suresh   25
# 3  Sathish   30

# %%
df2.loc[1]
# Out:
# Name    Ramesh
# Age         20
# Name: 1, dtype: object

# %%
print(len(df2.index))
# Out:
# 3

# %%
df2.loc[4] = ['Bunny',35]
df2
# Out:
#       Name  Age
# 1   Ramesh   20
# 2   Suresh   25
# 3  Sathish   30
# 4    Bunny   35

# %%
df2.loc['A'] = ['Sunny',40]
df2
# Out:
#       Name  Age
# 1   Ramesh   20
# 2   Suresh   25
# 3  Sathish   30
# 4    Bunny   35
# A    Sunny   40

# %% [markdown]
# $Step-7$:
#
# **Drop the column**
#
# - Before drop column
# - I will create a new column
# - I have only 2 columns are there

# %%
Names = ['Ramesh','Suresh','Sathish']
Age = [20,25,30]
df1 = pd.DataFrame(zip(Names,Age),
                  columns=['Names','Age'],
                  index = [0,1,2])
df1['City'] = ['Hyd','Blr','Chennai']
df1
# Out:
#      Names  Age     City
# 0   Ramesh   20      Hyd
# 1   Suresh   25      Blr
# 2  Sathish   30  Chennai

# %%
# Axis = 1 It reference Column
# Axis = 0 It reference rows
# The result you want to overrride or save in another variable
df2 = df1.drop('City',axis=1)
df2
# Out:
#      Names  Age
# 0   Ramesh   20
# 1   Suresh   25
# 2  Sathish   30

# %%
df1
# Out:
#      Names  Age     City
# 0   Ramesh   20      Hyd
# 1   Suresh   25      Blr
# 2  Sathish   30  Chennai

# %%
Names = ['Ramesh','Suresh','Sathish']
Age = [20,25,30]
df1 = pd.DataFrame(zip(Names,Age),
                  columns=['Names','Age'],
                  index = [0,1,2])
df1['City'] = ['Hyd','Blr','Chennai']

df1.drop('City',axis=1, inplace=True)
df1
# Out:
#      Names  Age
# 0   Ramesh   20
# 1   Suresh   25
# 2  Sathish   30

# %%
# Drop A Row
df1.drop(2, inplace=True)

# %%
df1
# Out:
#     Names  Age
# 0  Ramesh   20
# 1  Suresh   25

# %% [markdown]
# $Step-9$
#
# **Save the df1 in local file**

# %%
# Read data file in serate foldr
# you need to provide path
# Write th eoutput in seperate folder
# you need to provide path
# folder location + name of the file + extension

file_path = "C:\\Users\\HP\\OneDrive\\Saurav-Personal\\Documents\\NareshIT\\DataScience\\Datafiles\\new_df1.csv"
df1.to_csv(file_path, index=False)

# %%
# First read
pd.read_csv(file_path)
# Out:
#      Names  Age
# 0   Ramesh   20
# 1   Suresh   25
# 2  Sathish   30

# %%
# Same folder
df1.to_csv('output1.csv', index=False)

# %%
pd.read_csv('output1.csv')
# Out:
#      Names  Age
# 0   Ramesh   20
# 1   Suresh   25
# 2  Sathish   30

# %% [markdown]
# $Method-2$
#
# ## Create a Dataframe using Dictionary ##

# %%
d1 = {'Names' : ['Ramesh', 'Suresh', 'Sathish'],
     'Age' : [20,25,30]}
d1

# Keys consider a Column names
# Values consider a rows
# Out:
# {'Names': ['Ramesh', 'Suresh', 'Sathish'], 'Age': [20, 25, 30]}

# %%
pd.DataFrame(d1)
# Out:
#      Names  Age
# 0   Ramesh   20
# 1   Suresh   25
# 2  Sathish   30

# %% [markdown]
# $Method-3$

# %%
# Creare a Empty dataframe

df1 = pd.DataFrame()
df1
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df1['Fruite'] = ['Apple','Banana','Grapes']
df1
# Out:
#    Fruite
# 0   Apple
# 1  Banana
# 2  Grapes

# %%
import random

df2 = pd.DataFrame()
evet_list = []
for i in range(5):
    num = random.randint(20,50)
    if num % 2 == 0:
        evet_list.append(num)
        
evet_list
# Out:
# [24, 32, 20, 32, 22]

# %%
df2['Even'] = evet_list
df2
# Out:
#    Even
# 0    24
# 1    32
# 2    20
# 3    32
# 4    22

# %%
df2['Odd'] = [1,3,5,7,9]
df2
# Out:
#    Even  Odd
# 0    24    1
# 1    32    3
# 2    20    5
# 3    32    7
# 4    22    9
