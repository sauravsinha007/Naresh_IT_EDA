# %% [markdown]
# **Import required packages**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = "C:\\Users\\HP\\OneDrive\\Saurav-Personal\\Documents\\NareshIT\\DataScience\\Datafiles\\Visadataset.csv"
visa_df = pd.read_csv(file_path)
visa_df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# 1       83425.6500         Year                  Y   Certified
# 2      122996.8600         Year                  Y      Denied
# 3       83434.0300         Year                  Y      Denied
# 4      149907.3900         Year                  Y   Certified

# %%
visa_df.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %% [markdown]
# $prevailing$-$wage$

# %%
p_wage = visa_df['prevailing_wage']
p_wage.head()
# Out:
# 0       592.2029
# 1     83425.6500
# 2    122996.8600
# 3     83434.0300
# 4    149907.3900
# Name: prevailing_wage, dtype: float64

# %%
- count
-max
-min
-mean
-median
-25p
-50p
-75p

# %%
p_wage.count()
# Out:
# 25480

# %%
p_wage = visa_df[['prevailing_wage']]
p_wage.count().iloc[0]
# Out:
# 25480

# %%
p_wage = visa_df['prevailing_wage']
wage_count = p_wage.count()
wage_mean = round(p_wage.mean(),2)
wage_median = round(p_wage.median(),2)
wage_max = round(p_wage.max(),2)
wage_min = round(p_wage.min(),2)

print(wage_count)
print(wage_mean)
print(wage_median)
print(wage_max)
print(wage_min)
# Out:
# 25480
# 74455.81
# 70308.21
# 319210.27
# 2.14

# %%
list1 = [wage_count,wage_max,wage_min,wage_mean,wage_median]
index_list = ['count','max','min','mean','median']
df =pd.DataFrame(list1,
                 columns=['prevailaing_wage'],
                index = index_list)
df
# Out:
#         prevailaing_wage
# count           25480.00
# max            319210.27
# min                 2.14
# mean            74455.81
# median          70308.21

# %%
# Numerical columns seperately
num_cols = visa_df.select_dtypes(exclude='object').columns
num_cols

for i in num_cols:
    print(i)
# Out:
# no_of_employees
# yr_of_estab
# prevailing_wage

# %%
dict1 = {}
for i in num_cols:
    print(i)
    val = visa_df[i]
    count = val.count()
    mean = round(val.mean(),2)
    median = round(val.median(),2)
    max1 = round(val.max(),2)
    min1 = round(val.min(),2)
    list1 = [count,max1,min1,mean,median]
    dict1[i] = list1
    
    
index_list = ['count','max','min','mean','median']
number_df =pd.DataFrame(dict1,
                index = index_list)
number_df.to_csv('number_df.csv')
number_df
# Out:
# no_of_employees
# yr_of_estab
# prevailing_wage
#         no_of_employees  yr_of_estab  prevailing_wage
# count          25480.00     25480.00         25480.00
# max           602069.00      2016.00        319210.27
# min              -26.00      1800.00             2.14
# mean            5667.04      1979.41         74455.81
# median          2109.00      1997.00         70308.21

# %%
visa_df.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000

# %%
p_wage = visa_df['prevailing_wage']
wage_count = p_wage.count()
wage_mean = round(p_wage.mean(),2)
wage_median = round(p_wage.median(),2)
wage_max = round(p_wage.max(),2)
wage_min = round(p_wage.min(),2)
wage_std = round(p_wage.std(),2)

print(wage_count)
print(wage_mean)
print(wage_median)
print(wage_max)
print(wage_min)
print(wage_std)
      
list1 = [wage_count,wage_max,wage_min,wage_mean,wage_median,wage_std]
index_list = ['count','max','min','mean','median','std']
df =pd.DataFrame(list1,
                 columns=['prevailaing_wage'],
                index = index_list)
df
# Out:
# 25480
# 74455.81
# 70308.21
# 319210.27
# 2.14
# 52815.94
#         prevailaing_wage
# count           25480.00
# max            319210.27
# min                 2.14
# mean            74455.81
# median          70308.21
# std             52815.94

# %%
# what ever we did the ca;culations on above
# by using pandas dataframe way
# the same we can achive by numpy package also

# %%
# wage_mean =  round(p_wage.mean(),2) ---> pandas

p_wage = visa_df['prevailing_wage']
np.mean(p_wage)
np.median(p_wage)
np.max(p_wage)
np.min(p_wage)
np.std(p_wage)
# Out:
# 52814.90589711402

# %%
np.median(p_wage)
# Out:
# 70308.20999999999

# %% [markdown]
# **percentile-quantile**
#
# - In the numpy package we have np.percentile() and np.quantile
# - percentile: if you want to 25p   25
# - quantile: q1=25p (0.25)    q2=50p     q3=75p
#
# - Assume that a student got 120 Marks 95p
#
# - 95% of students has marks below 120

# %%
np.percentile(p_wage,25)
# Out:
# 34015.479999999996

# %%
np.quantile(p_wage,0.25)
# Out:
# 34015.479999999996

# %%
p_wage = visa_df['prevailing_wage']
#### Pamdas series ##############
wage_count = p_wage.count()
wage_mean = round(p_wage.mean(),2)
wage_median = round(p_wage.median(),2)
wage_max = round(p_wage.max(),2)
wage_min = round(p_wage.min(),2)
wage_std = round(p_wage.std(),2)
####### Numpy ##################
wage_25p = round(np.percentile(p_wage,25),2)
wage_50p = round(np.percentile(p_wage,50),2)
wage_75p = round(np.percentile(p_wage,75),2)

print(wage_count)
print(wage_mean)
print(wage_median)
print(wage_max)
print(wage_min)
print(wage_std)
      
list1 = [wage_count,wage_max,wage_min,wage_mean,wage_median,
         wage_std,wage_25p,wage_50p,wage_75p]
index_list = ['count','max','min','mean','median',
              'std','25%','50%','75%']
df =pd.DataFrame(list1,
                 columns=['prevailaing_wage'],
                index = index_list)
df
# Out:
# 25480
# 74455.81
# 70308.21
# 319210.27
# 2.14
# 52815.94
#         prevailaing_wage
# count           25480.00
# max            319210.27
# min                 2.14
# mean            74455.81
# median          70308.21
# std             52815.94
# 25%             34015.48
# 50%             70308.21
# 75%            107735.51

# %%
num_cols = visa_df.select_dtypes(exclude='object').columns
num_cols
dict1 = {}
for i in num_cols:
    print(i)
    val = visa_df[i]
    count = val.count()
    mean = round(val.mean(),2)
    median = round(val.median(),2)
    max1 = round(val.max(),2)
    min1 = round(val.min(),2)
    wage_std = round(p_wage.std(),2)
    wage_25p = round(np.percentile(p_wage,25),2)
    wage_50p = round(np.percentile(p_wage,50),2)
    wage_75p = round(np.percentile(p_wage,75),2)
    list1 = [count,max1,min1,mean,median,wage_std,
             wage_25p,wage_50p,wage_75p]
    dict1[i] = list1
    
    
index_list = ['count','max','min','mean','median'
             ,'std','25%','50%','75%']
number_df =pd.DataFrame(dict1,
                index = index_list)
number_df.to_csv('number_df.csv')
number_df
# Out:
# no_of_employees
# yr_of_estab
# prevailing_wage
#         no_of_employees  yr_of_estab  prevailing_wage
# count          25480.00     25480.00         25480.00
# max           602069.00      2016.00        319210.27
# min              -26.00      1800.00             2.14
# mean            5667.04      1979.41         74455.81
# median          2109.00      1997.00         70308.21
# std            52815.94     52815.94         52815.94
# 25%            34015.48     34015.48         34015.48
# 50%            70308.21     70308.21         70308.21
# 75%           107735.51    107735.51        107735.51

# %%
#pwage 25p = 34015

#25% of total employees has wages below 34015

25*(25480)/100
6370 employees has wages lesss than 30415
# Out:
# 6370.0

# %%
p_wage[p_wage < 34015]
# Out:
# 0          592.2029
# 7          418.2298
# 12       28663.0500
# 16        3706.7900
# 17       16132.6100
#             ...
# 25461       54.9196
# 25465      481.2238
# 25466     6973.4000
# 25470      516.4101
# 25473    22845.5600
# Name: prevailing_wage, Length: 6370, dtype: float64

# %%
p_wage = visa_df['prevailing_wage']
p_wage[p_wage<34015]
# Out:
# 0          592.2029
# 7          418.2298
# 12       28663.0500
# 16        3706.7900
# 17       16132.6100
#             ...
# 25461       54.9196
# 25465      481.2238
# 25466     6973.4000
# 25470      516.4101
# 25473    22845.5600
# Name: prevailing_wage, Length: 6370, dtype: float64

# %%
len(p_wage[p_wage<34015])
# Out:
# 6370

# %%
len(p_wage[p_wage<np.percentile(p_wage,25)])
# Out:
# 6370

# %%
p_wage = visa_df['prevailing_wage']
count_25 = len(p_wage[p_wage<np.percentile(p_wage,25)])
count_50 = len(p_wage[p_wage<np.percentile(p_wage,50)])
count_75 = len(p_wage[p_wage<np.percentile(p_wage,75)])

(count_25,count_50,count_75)
# Out:
# (6370, 12740, 19110)

# %%
p_wage = visa_df['prevailing_wage']
count_25 = len(p_wage[p_wage<np.percentile(p_wage,25)])
count_50 = len(p_wage[p_wage<np.percentile(p_wage,50)])
count_75 = len(p_wage[p_wage<np.percentile(p_wage,75)])

l1 = ['Count of 25%','Count of 50%','Count of 75%']
l2 = [count_25,count_50,count_75]
d1 = pd.DataFrame(zip(l1,l2),columns=['Till per','Count'])
plt.bar('Till per','Count',data=d1)
# Out:
# <BarContainer object of 3 artists>

# %%
# you want to extract a dataframe
# which has wages less than 34015
# 10025 members

# %%
# step-1: take the reference column first
# step-2: Apply the condition
#           it will provide True or False
# Step3: Apply the original datadrame on top of that
#     so that it will give only True value

p_wage = visa_df['prevailing_wage']
p_25 = np.percentile(p_wage,25)
con = p_wage<p_25
visa_df[con]

# visa_df[visa_df['prevailing_wage']<34015]
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 0         EZYV01           Asia           High School                  N
# 7         EZYV08  North America            Bachelor's                  Y
# 12        EZYV13           Asia            Bachelor's                  Y
# 16        EZYV17         Europe              Master's                  Y
# 17        EZYV18           Asia              Master's                  Y
# ...          ...            ...                   ...                ...
# 25461  EZYV25462           Asia              Master's                  Y
# 25465  EZYV25466  North America           High School                  N
# 25466  EZYV25467         Europe            Bachelor's                  Y
# 25470  EZYV25471  North America              Master's                  Y
# 25473  EZYV25474           Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 7                         N             3035         1924
# 12                        N           123876         1963
# 16                        N            76638         1991
# 17                        N             2747         2001
# ...                     ...              ...          ...
# 25461                     N             2861         2004
# 25465                     N             2577         1995
# 25466                     N             1938         2005
# 25470                     N             2272         1970
# 25473                     N             2421         2007
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 7                     West         418.2298         Hour                  Y
# 12               Northeast       28663.0500         Year                  Y
# 16                 Midwest        3706.7900         Year                  Y
# 17                    West       16132.6100         Year                  Y
# ...                    ...              ...          ...                ...
# 25461                 West          54.9196         Hour                  Y
# 25465                South         481.2238         Hour                  Y
# 25466                 West        6973.4000         Year                  Y
# 25470            Northeast         516.4101         Hour                  Y
# 25473            Northeast       22845.5600         Year                  Y
#
#       case_status
# 0          Denied
# 7          Denied
# 12      Certified
# 16      Certified
# 17      Certified
# ...           ...
# 25461      Denied
# 25465   Certified
# 25466      Denied
# 25470   Certified
# 25473   Certified
#
# [6370 rows x 12 columns]

# %%
p_wage = visa_df['prevailing_wage']
p_50 = np.percentile(p_wage,50)
con_50 = p_wage<p_50
visa_df[con_50]
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 0         EZYV01           Asia           High School                  N
# 6         EZYV07           Asia            Bachelor's                  N
# 7         EZYV08  North America            Bachelor's                  Y
# 9         EZYV10         Europe             Doctorate                  Y
# 12        EZYV13           Asia            Bachelor's                  Y
# ...          ...            ...                   ...                ...
# 25465  EZYV25466  North America           High School                  N
# 25466  EZYV25467         Europe            Bachelor's                  Y
# 25470  EZYV25471  North America              Master's                  Y
# 25473  EZYV25474           Asia            Bachelor's                  Y
# 25474  EZYV25475         Africa             Doctorate                  N
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 6                         N             4985         1994
# 7                         N             3035         1924
# 9                         N             2251         1995
# 12                        N           123876         1963
# ...                     ...              ...          ...
# 25465                     N             2577         1995
# 25466                     N             1938         2005
# 25470                     N             2272         1970
# 25473                     N             2421         2007
# 25474                     N             2594         1979
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 6                    South       53635.3900         Year                  Y
# 7                     West         418.2298         Hour                  Y
# 9                    South       67514.7600         Year                  Y
# 12               Northeast       28663.0500         Year                  Y
# ...                    ...              ...          ...                ...
# 25465                South         481.2238         Hour                  Y
# 25466                 West        6973.4000         Year                  Y
# 25470            Northeast         516.4101         Hour                  Y
# 25473            Northeast       22845.5600         Year                  Y
# 25474            Northeast       51104.7800         Year                  Y
#
#       case_status
# 0          Denied
# 6       Certified
# 7          Denied
# 9       Certified
# 12      Certified
# ...           ...
# 25465   Certified
# 25466      Denied
# 25470   Certified
# 25473   Certified
# 25474   Certified
#
# [12740 rows x 12 columns]

# %%
#b/w  25p to 50%
# b/w 34k to 70k
p_wage = visa_df['prevailing_wage']
p_25 = np.percentile(p_wage,25)
p_50 = np.percentile(p_wage,50)
con_1 = p_wage>p_25
con_2 = p_wage<p_50
visa_df[con_1 & con_2]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 6         EZYV07      Asia            Bachelor's                  N
# 9         EZYV10    Europe             Doctorate                  Y
# 22        EZYV23      Asia              Master's                  Y
# 28        EZYV29      Asia              Master's                  Y
# 38        EZYV39      Asia            Bachelor's                  Y
# ...          ...       ...                   ...                ...
# 25449  EZYV25450      Asia            Bachelor's                  Y
# 25454  EZYV25455      Asia            Bachelor's                  N
# 25456  EZYV25457      Asia            Bachelor's                  Y
# 25459  EZYV25460      Asia           High School                  Y
# 25474  EZYV25475    Africa             Doctorate                  N
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 6                         N             4985         1994
# 9                         N             2251         1995
# 22                        N             2878         1968
# 28                        N               18         2004
# 38                        Y             2206         1909
# ...                     ...              ...          ...
# 25449                     N             3017         2000
# 25454                     N             1316         2007
# 25456                     N              998         1996
# 25459                     N             4727         1990
# 25474                     N             2594         1979
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 6                    South         53635.39         Year                  Y
# 9                    South         67514.76         Year                  Y
# 22                    West         45642.39         Year                  Y
# 28               Northeast         40925.86         Year                  Y
# 38               Northeast         50960.01         Year                  Y
# ...                    ...              ...          ...                ...
# 25449                 West         39313.00         Year                  Y
# 25454                South         62844.97         Year                  Y
# 25456                South         67340.65         Year                  Y
# 25459              Midwest         53952.84         Year                  Y
# 25474            Northeast         51104.78         Year                  Y
#
#       case_status
# 6       Certified
# 9       Certified
# 22      Certified
# 28      Certified
# 38      Certified
# ...           ...
# 25449   Certified
# 25454      Denied
# 25456   Certified
# 25459      Denied
# 25474   Certified
#
# [6370 rows x 12 columns]

# %%
12740 - 6370 # 6370

till 50 = 12740
till 25 = 6370
# Out:
# 6370

# %%
# <25   >75
p_wage = visa_df['prevailing_wage']
p_25 = np.percentile(p_wage,25)
p_75 = np.percentile(p_wage,75)
con_1 = p_wage<p_25
con_2 = p_wage>p_75
visa_df[con_1 | con_2]
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 0         EZYV01           Asia           High School                  N
# 2         EZYV03           Asia            Bachelor's                  N
# 4         EZYV05         Africa              Master's                  Y
# 7         EZYV08  North America            Bachelor's                  Y
# 12        EZYV13           Asia            Bachelor's                  Y
# ...          ...            ...                   ...                ...
# 25469  EZYV25470  North America              Master's                  Y
# 25470  EZYV25471  North America              Master's                  Y
# 25473  EZYV25474           Asia            Bachelor's                  Y
# 25476  EZYV25477           Asia           High School                  Y
# 25477  EZYV25478           Asia              Master's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 2                         Y            44444         2008
# 4                         N             1082         2005
# 7                         N             3035         1924
# 12                        N           123876         1963
# ...                     ...              ...          ...
# 25469                     N             2261         1997
# 25470                     N             2272         1970
# 25473                     N             2421         2007
# 25476                     N             3274         2006
# 25477                     N             1121         1910
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 2                     West      122996.8600         Year                  Y
# 4                    South      149907.3900         Year                  Y
# 7                     West         418.2298         Hour                  Y
# 12               Northeast       28663.0500         Year                  Y
# ...                    ...              ...          ...                ...
# 25469            Northeast      273772.4700         Year                  N
# 25470            Northeast         516.4101         Hour                  Y
# 25473            Northeast       22845.5600         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
#
#       case_status
# 0          Denied
# 2          Denied
# 4       Certified
# 7          Denied
# 12      Certified
# ...           ...
# 25469   Certified
# 25470   Certified
# 25473   Certified
# 25476   Certified
# 25477   Certified
#
# [12740 rows x 12 columns]

# %% [markdown]
# $Histogram$

# %% [markdown]
# - From raw data will make class interval
# - Will Count the observations in each class intervals
# - Frequency distribution table
# - Plot Frequency distribution table is Histogram

# %%
p_wage= visa_df['prevailing_wage']
frequency,interval,n = plt.hist(p_wage, bins=40)
frequency,interval
# len(a),len(b)
# Out:
# (array([2992.,  871., 1005., 1170., 1242., 1434., 1385., 1443., 1444.,
#         1445., 1457., 1335., 1268., 1217., 1088.,  978.,  807.,  645.,
#          509.,  373.,  264.,  144.,  105.,  111.,  107.,   99.,   88.,
#           79.,   65.,   64.,   58.,   53.,   33.,   33.,   29.,   19.,
#            7.,    3.,    6.,    5.]),
#  array([2.13670000e+00, 7.98234003e+03, 1.59625434e+04, 2.39427467e+04,
#         3.19229500e+04, 3.99031534e+04, 4.78833567e+04, 5.58635600e+04,
#         6.38437634e+04, 7.18239667e+04, 7.98041700e+04, 8.77843734e+04,
#         9.57645767e+04, 1.03744780e+05, 1.11724983e+05, 1.19705187e+05,
#         1.27685390e+05, 1.35665593e+05, 1.43645797e+05, 1.51626000e+05,
#         1.59606203e+05, 1.67586407e+05, 1.75566610e+05, 1.83546813e+05,
#         1.91527017e+05, 1.99507220e+05, 2.07487423e+05, 2.15467627e+05,
#         2.23447830e+05, 2.31428033e+05, 2.39408237e+05, 2.47388440e+05,
#         2.55368643e+05, 2.63348847e+05, 2.71329050e+05, 2.79309253e+05,
#         2.87289457e+05, 2.95269660e+05, 3.03249863e+05, 3.11230067e+05,
#         3.19210270e+05]))

# %%
2.13670000e+00 # 2.13
7.98234003e+03  # 7.98234003 * 1000= 7982
# Out:
# 7982.34003

# %%
# 2.13 to 7982 (2992)

p_wage= visa_df['prevailing_wage']
con1 = p_wage > 2.13
con2 = p_wage<7982.34
len(visa_df[con1&con2])
# Out:
# 2992

# %%
p_wage= visa_df['prevailing_wage']
con1 = p_wage > 7.98234003e+03
con2 = p_wage < 1.59625434e+04
len(visa_df[con1&con2])
# Out:
# 871

# %%
p_wage.values

l1 = sorted(p_wage.values)
l1
# Out:
# [2.1367,
#  2.9561,
#  3.0031,
#  3.3188,
#  3.4889,
#  5.0899,
#  5.1868,
#  5.4108,
#  5.6396,
#  6.3305,
#  7.0647,
#  8.5186,
#  9.1753,
#  9.5331,
#  10.1111,
#  10.5551,
#  10.9041,
#  11.3078,
#  11.4219,
#  11.4473,
#  11.8704,
#  12.2234,
#  12.99,
#  14.9093,
#  15.6472,
#  15.7716,
#  16.0596,
#  16.4637,
#  16.7318,
#  17.4747,
#  17.519,
#  17.5508,
#  17.8912,
#  18.4425,
#  19.3731,
#  20.1896,
#  21.1327,
#  22.7435,
#  23.0599,
#  23.4378,
#  23.6074,
#  24.4888,
#  24.7965,
#  25.0117,
#  27.5544,
#  28.9508,
#  30.6131,
#  30.7996,
#  30.8737,
#  31.1755,
#  32.9286,
#  33.0953,
#  34.5971,
#  35.1594,
#  35.335,
#  36.0253,
#  37.1854,
#  37.1919,
#  37.6142,
#  38.4261,
#  38.9863,
#  39.225,
#  39.8843,
#  40.1191,
#  40.9826,
#  41.759,
#  41.9771,
#  42.4315,
#  42.559,
#  42.7705,
#  43.7525,
#  44.4207,
#  44.5953,
#  44.8222,
#  44.9147,
#  45.0484,
#  45.9315,
#  45.9405,
#  45.9551,
#  46.0198,
#  46.1228,
#  46.5932,
#  47.2736,
#  47.4395,
#  47.4872,
#  48.0065,
#  48.0773,
#  48.1309,
#  48.5167,
#  49.9985,
#  50.0723,
#  50.2928,
#  50.4192,
#  50.5535,
#  50.8813,
#  51.6812,
#  51.8503,
#  52.0516,
#  52.8246,
#  52.8519,
#  53.0071,
#  53.535,
#  54.5863,
#  54.9196,
#  55.6048,
#  55.7084,
#  56.1953,
#  56.5217,
#  56.6515,
#  57.2276,
#  57.9863,
#  58.3954,
#  58.5331,
#  58.5781,
#  58.7389,
#  59.015,
#  59.0859,
#  59.848,
#  61.1329,
#  61.409,
#  62.9598,
#  63.7364,
#  65.0665,
#  65.1106,
#  65.8154,
#  66.1509,
#  66.3423,
#  68.5833,
#  69.6449,
#  70.599,
#  71.2856,
#  72.7666,
#  73.582,
#  73.924,
#  74.2851,
#  74.3597,
#  74.4049,
#  74.5157,
#  77.2403,
#  77.3424,
#  77.3892,
#  77.4716,
#  77.4976,
#  78.6227,
#  78.6823,
#  79.1099,
#  79.1718,
#  79.8269,
#  81.5533,
#  82.0029,
#  84.1165,
#  84.9745,
#  85.7085,
#  85.9367,
#  88.6958,
#  89.2557,
#  89.4706,
#  89.5992,
#  89.7288,
#  92.6112,
#  92.7343,
#  93.7639,
#  94.1546,
#  94.6627,
#  95.7322,
#  95.8502,
#  96.0576,
#  96.1061,
#  96.6666,
#  97.3218,
#  97.5946,
#  97.6734,
#  98.6015,
#  99.3492,
#  99.5833,
#  99.6744,
#  100.0,
#  100.01,
#  100.1,
#  100.14,
#  100.17,
#  100.41,
#  100.4576,
#  100.51,
#  100.5384,
#  100.66,
#  100.66,
#  100.73,
#  100.7597,
#  100.7651,
#  100.91,
#  100.93,
#  100.95,
#  100.9604,
#  100.98,
#  101.1,
#  101.22,
#  101.26,
#  101.27,
#  101.42,
#  101.51,
#  101.56,
#  101.66,
#  101.71,
#  101.72,
#  101.73,
#  101.8,
#  101.8936,
#  101.8983,
#  101.93,
#  101.99,
#  102.0197,
#  102.11,
#  102.16,
#  102.19,
#  102.21,
#  102.32,
#  102.47,
#  102.6,
#  102.7,
#  102.7,
#  102.77,
#  102.89,
#  102.94,
#  102.97,
#  103.07,
#  103.2216,
#  103.36,
#  103.47,
#  103.64,
#  103.93,
#  103.97,
#  104.11,
#  104.17,
#  104.23,
#  104.49,
#  104.53,
#  104.56,
#  104.59,
#  104.67,
#  104.77,
#  104.8,
#  104.83,
#  104.85,
#  105.08,
#  105.1507,
#  105.22,
#  105.24,
#  105.3209,
#  105.44,
#  105.63,
#  105.81,
#  105.87,
#  105.96,
#  105.96,
#  106.07,
#  106.22,
#  106.25,
#  106.43,
#  106.55,
#  106.8,
#  106.8412,
#  106.91,
#  107.08,
#  107.1327,
#  107.36,
#  107.38,
#  107.43,
#  107.6405,
#  107.65,
#  107.6856,
#  108.04,
#  108.12,
#  108.12,
#  108.31,
#  108.46,
#  108.47,
#  108.59,
#  108.664,
#  108.81,
#  108.8813,
#  109.0,
#  109.06,
#  109.06,
#  109.13,
#  109.24,
#  109.32,
#  109.34,
#  109.4171,
#  109.48,
#  109.76,
#  109.84,
#  109.88,
#  109.96,
#  109.97,
#  110.28,
#  110.3,
#  110.41,
#  110.5,
#  110.51,
#  110.51,
#  110.6383,
#  110.85,
#  111.11,
#  111.11,
#  111.14,
#  111.2,
#  111.21,
#  111.42,
#  111.5107,
#  111.56,
#  111.59,
#  111.64,
#  111.73,
#  111.74,
#  111.82,
#  111.99,
#  112.16,
#  112.68,
#  112.71,
#  112.86,
#  113.09,
#  113.23,
#  113.236,
#  113.49,
#  113.6,
#  113.6,
#  113.61,
#  113.8323,
#  113.88,
#  113.96,
#  114.044,
#  114.12,
#  114.78,
#  114.82,
#  115.0661,
#  115.1174,
#  115.12,
#  115.19,
#  115.2475,
#  115.55,
#  115.63,
#  115.78,
#  115.81,
#  115.85,
#  115.91,
#  116.0,
#  116.04,
#  116.37,
#  116.38,
#  116.51,
#  116.5558,
#  116.56,
#  116.75,
#  116.87,
#  117.0447,
#  117.39,
#  117.42,
#  117.59,
#  117.65,
#  117.72,
#  117.77,
#  117.85,
#  118.1343,
#  118.29,
#  118.3811,
#  118.39,
#  118.41,
#  118.43,
#  118.43,
#  118.49,
#  118.76,
#  118.84,
#  119.03,
#  119.22,
#  119.34,
#  119.79,
#  119.82,
#  119.88,
#  119.9211,
#  120.27,
#  120.56,
#  120.93,
#  121.11,
#  121.24,
#  121.41,
#  121.6,
#  121.65,
#  122.3,
#  122.55,
#  122.57,
#  122.6374,
#  122.65,
#  122.65,
#  123.0441,
#  123.15,
#  123.25,
#  123.2997,
#  123.42,
#  123.44,
#  123.7616,
#  124.1585,
#  124.21,
#  124.49,
#  124.53,
#  124.5775,
#  124.73,
#  124.92,
#  124.95,
#  124.97,
#  125.4,
#  125.42,
#  125.5413,
#  125.5821,
#  125.76,
#  125.79,
#  126.1176,
#  126.28,
#  126.4943,
#  126.5075,
#  126.67,
#  126.69,
#  126.86,
#  127.1379,
#  127.31,
#  127.3734,
#  127.5109,
#  127.89,
#  127.89,
#  128.01,
#  128.12,
#  128.23,
#  128.27,
#  128.37,
#  128.6745,
#  128.76,
#  128.8,
#  128.93,
#  129.35,
#  129.47,
#  129.62,
#  129.91,
#  130.0398,
#  130.0671,
#  130.18,
#  130.27,
#  130.29,
#  130.4348,
#  130.63,
#  130.69,
#  130.83,
#  131.0796,
#  131.12,
#  131.51,
#  131.6884,
#  131.74,
#  131.8251,
#  131.88,
#  132.04,
#  132.24,
#  132.76,
#  132.82,
#  132.93,
#  133.33,
#  133.89,
#  134.0617,
#  134.15,
#  134.15,
#  134.85,
#  134.89,
#  135.17,
#  135.3,
#  135.3652,
#  135.38,
#  136.2184,
#  136.3614,
#  136.5,
#  136.5063,
#  136.51,
#  136.56,
#  136.7014,
#  136.77,
#  137.15,
#  137.57,
#  137.69,
#  137.76,
#  138.0747,
#  138.5358,
#  138.69,
#  138.76,
#  138.76,
#  138.7658,
#  138.875,
#  139.11,
#  139.6479,
#  139.7277,
#  139.74,
#  139.8032,
#  140.59,
#  140.82,
#  140.85,
#  141.32,
#  141.3244,
#  141.3424,
#  141.51,
#  141.57,
#  141.6406,
#  141.72,
#  141.7329,
#  142.82,
#  142.8752,
#  143.346,
#  143.4372,
#  144.56,
#  144.73,
#  144.76,
#  145.1134,
#  145.17,
#  145.72,
#  145.74,
#  146.08,
#  146.3,
#  146.48,
#  146.5569,
#  147.0,
#  147.07,
#  147.1202,
#  147.13,
#  147.22,
#  147.32,
#  147.33,
#  147.41,
#  147.7032,
#  148.35,
#  149.36,
#  149.4644,
#  149.57,
#  149.58,
#  149.7,
#  149.86,
#  150.1045,
#  150.3805,
#  150.4,
#  151.1779,
#  151.2522,
#  151.3908,
#  151.7829,
#  152.16,
#  152.59,
#  152.7003,
#  152.7112,
#  152.7813,
#  152.89,
#  152.91,
#  153.0232,
#  153.11,
#  153.4356,
#  153.73,
#  153.77,
#  153.98,
#  154.0126,
#  154.1,
#  154.26,
#  154.42,
#  154.53,
#  155.0951,
#  155.67,
#  155.738,
#  155.98,
#  156.3038,
#  156.3903,
#  156.4177,
#  156.607,
#  156.66,
#  156.79,
#  156.8268,
#  157.1777,
#  157.66,
#  158.36,
#  158.3807,
#  158.4,
#  158.5,
#  158.97,
#  159.09,
#  159.2978,
#  160.0882,
#  160.3648,
#  161.3074,
#  161.33,
#  161.556,
#  162.92,
#  163.07,
#  164.0089,
#  164.86,
#  165.0605,
#  165.2722,
#  165.8365,
#  166.67,
#  166.8968,
#  167.2888,
#  167.9421,
#  167.9464,
#  168.0793,
#  168.1558,
#  168.62,
#  168.7141,
#  169.4047,
#  169.46,
#  170.9434,
#  171.0384,
#  171.0931,
#  171.5546,
#  171.63,
#  171.9695,
#  172.72,
#  173.24,
#  173.3297,
#  173.5091,
#  173.9685,
#  174.0,
#  174.1887,
#  174.35,
#  174.594,
#  175.36,
#  176.13,
#  176.34,
#  176.3821,
#  176.5574,
#  176.6921,
#  176.76,
#  176.8885,
#  177.69,
#  177.8352,
#  177.8673,
#  177.89,
#  178.0827,
#  178.5724,
#  178.5808,
#  178.84,
#  178.8675,
#  179.62,
#  179.6437,
#  180.1,
#  180.19,
#  180.9354,
#  181.3927,
#  181.87,
#  182.0907,
#  182.37,
#  182.58,
#  182.5918,
#  182.8141,
#  183.9091,
#  184.74,
#  185.2334,
#  185.7137,
#  185.7184,
#  186.3233,
#  186.7734,
#  186.78,
#  187.0879,
#  187.42,
#  188.6818,
#  189.0437,
#  189.0481,
#  189.5454,
#  190.2601,
#  191.6301,
#  192.06,
#  192.157,
#  192.3292,
#  192.37,
#  192.5117,
#  192.8448,
#  192.8729,
#  193.0432,
#  194.01,
#  194.503,
#  195.0526,
#  195.1899,
#  196.4013,
#  196.4283,
#  196.669,
#  197.25,
#  197.9846,
#  198.4095,
#  199.5532,
#  199.83,
#  200.448,
#  202.4744,
#  202.5198,
#  203.1459,
#  203.4146,
#  203.6589,
#  204.6484,
#  204.8606,
#  205.1512,
#  205.2109,
#  205.2435,
#  205.3793,
#  205.4479,
#  205.58,
#  205.6246,
#  206.1632,
#  206.3,
#  206.41,
#  206.4596,
#  207.1684,
#  207.1837,
#  207.2492,
#  208.5263,
#  209.645,
#  209.88,
#  210.5073,
#  210.7526,
#  210.9267,
#  211.0409,
#  212.2408,
#  212.2737,
#  213.4232,
#  214.93,
#  215.1,
#  215.1947,
#  215.9285,
#  216.15,
#  216.4821,
#  216.6439,
#  217.2719,
#  217.5757,
#  218.3542,
#  218.38,
#  219.0587,
#  219.07,
#  219.092,
#  219.92,
#  220.5704,
#  220.9686,
#  220.9902,
#  221.1209,
#  221.5887,
#  221.6878,
#  221.6987,
#  221.784,
#  222.3061,
#  222.3969,
#  222.6868,
#  222.8496,
#  223.0344,
#  224.0765,
#  224.1068,
#  225.4865,
#  225.5339,
#  225.6105,
#  225.6413,
#  226.0,
#  226.1194,
#  227.114,
#  227.1764,
#  227.7353,
#  227.8636,
#  228.0513,
#  228.2617,
#  228.3418,
#  228.6246,
#  229.99,
#  230.0556,
#  230.14,
#  230.327,
#  230.4357,
#  230.7013,
#  230.8072,
#  231.1253,
#  231.3117,
#  231.6706,
#  231.7069,
#  231.938,
#  232.6611,
#  232.7954,
#  232.808,
#  233.6391,
#  233.7907,
#  233.9425,
#  233.9733,
#  234.1894,
#  234.4957,
#  235.02,
#  235.23,
#  235.4483,
#  236.861,
#  237.4818,
#  237.9818,
#  238.0194,
#  238.0375,
#  238.3367,
#  238.8305,
#  239.1755,
#  239.3237,
#  239.6427,
#  240.7297,
#  241.6995,
#  242.0347,
#  243.2901,
#  245.727,
#  246.19,
#  246.3592,
#  246.81,
#  247.0206,
#  247.1333,
#  247.3649,
#  247.8871,
#  248.01,
#  248.0932,
#  248.3727,
#  248.6583,
#  249.1278,
#  249.9158,
#  250.7276,
#  250.8438,
#  251.8984,
#  252.2732,
#  252.43,
#  253.0191,
#  253.253,
#  253.7458,
#  253.7681,
#  254.5742,
#  254.778,
#  254.8773,
#  254.937,
#  255.3884,
#  255.7444,
#  255.91,
#  255.9271,
#  257.2413,
#  257.6062,
#  257.6129,
#  259.2239,
#  259.4118,
#  259.52,
#  260.6671,
#  260.945,
#  261.0801,
#  261.3887,
#  261.5594,
#  261.92,
#  261.9979,
#  262.4586,
#  263.1046,
#  264.5662,
#  264.5926,
#  264.5998,
#  264.9594,
#  265.7185,
#  266.7472,
#  267.1333,
#  268.1018,
#  268.1379,
#  268.7924,
#  268.8063,
#  269.8248,
#  269.8894,
#  269.9173,
#  270.2818,
#  271.0953,
#  272.7286,
#  272.996,
#  273.2008,
#  274.253,
#  274.2609,
#  274.3672,
#  274.7333,
#  275.0627,
#  275.7187,
#  276.5056,
#  276.646,
#  276.7576,
#  277.3422,
#  277.9945,
#  278.5388,
#  278.8894,
#  278.9787,
#  279.0018,
#  279.252,
#  280.2427,
#  280.4605,
#  281.1569,
#  282.1789,
#  283.2243,
#  283.4567,
#  283.5202,
#  283.8,
#  283.9495,
#  284.0018,
#  284.1352,
#  285.1525,
#  285.2286,
#  285.97,
#  286.2916,
#  286.4415,
#  286.8984,
#  287.2183,
#  287.8058,
#  288.124,
#  288.4735,
#  288.7112,
#  289.1,
#  289.1887,
#  289.8,
#  291.2804,
#  292.0427,
#  292.0788,
#  293.03,
#  293.0452,
#  293.3152,
#  294.402,
#  294.882,
#  294.9257,
#  295.2023,
#  295.9664,
#  297.1948,
#  297.5603,
#  297.7775,
#  298.1357,
#  298.4886,
#  298.5088,
#  298.8956,
#  299.2344,
#  299.6081,
#  299.7964,
#  299.9484,
#  300.0063,
#  300.9051,
#  301.0897,
#  301.2781,
#  301.3199,
#  301.6979,
#  301.8538,
#  301.9025,
#  302.2604,
#  302.6871,
#  302.7049,
#  303.0795,
#  303.4445,
#  304.0015,
#  304.0882,
#  305.0749,
#  305.6728,
#  306.9744,
#  307.1653,
#  307.5542,
#  307.7918,
#  307.9049,
#  308.3561,
#  308.6501,
#  308.7836,
#  309.3313,
#  309.4815,
#  309.606,
#  310.26,
#  310.6986,
#  311.1659,
#  311.3324,
#  311.4077,
#  312.7783,
#  312.8681,
#  313.4667,
#  313.835,
#  314.2371,
#  314.4384,
#  314.6393,
#  315.1887,
#  316.3918,
#  316.8972,
#  316.9498,
#  317.3444,
#  317.7013,
#  317.718,
#  318.4801,
#  318.5846,
#  318.6505,
#  318.6943,
#  318.964,
#  319.36,
#  319.498,
#  321.4051,
#  321.6259,
#  321.8313,
#  322.3961,
#  322.6621,
#  322.705,
#  322.8046,
#  323.7,
#  323.7899,
#  324.2135,
#  324.902,
#  324.9582,
#  325.1087,
#  325.1749,
#  325.303,
#  325.346,
#  ...]

# %%
table
interval                             count
2.136700000e+00 - 7.98234003e+03      2992

# %%
# pd.DataFrame(zip(frequency,interval), 
#              columns=['Frequency','Interval'])

# %%
visa_df.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000

# %%
plt.hist(p_wage)
# Out:
# (array([6038., 5504., 5681., 4551., 2334.,  624.,  373.,  240.,  114.,
#           21.]),
#  array([2.13670000e+00, 3.19229500e+04, 6.38437634e+04, 9.57645767e+04,
#         1.27685390e+05, 1.59606203e+05, 1.91527017e+05, 2.23447830e+05,
#         2.55368643e+05, 2.87289457e+05, 3.19210270e+05]),
#  <BarContainer object of 10 artists>)

# %%
sns.displot(visa_df['prevailing_wage'],
            bins=40)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(visa_df['prevailing_wage'],
           kind='ecdf')
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(visa_df['prevailing_wage'],
           kind='kde')
#kde: kernel distribution estimation
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(visa_df['prevailing_wage'])
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(visa_df['prevailing_wage'],
           kind='ecdf') # couumulative distribution plot
sns.displot(visa_df['prevailing_wage'],
           kind='kde') # kernal density estimation
sns.displot(visa_df['prevailing_wage'])# Histogram
